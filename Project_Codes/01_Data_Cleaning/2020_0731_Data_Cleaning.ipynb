# %% [markdown]
# In the following notebook, I'll be cleaning the raw data file pertaining to Lending Club loans taken out in Q1 2020.
#
# If you're interested, raw data can be found [here](https://www.lendingclub.com/statistics/additional-statistics?).

# %%
#Read in libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# **Set Notebook Preferences**

# %%
#Set pandas preferences
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

#Set matplotlib preferences


#Ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Read in Data**

# %%
#Path to raw data
path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Lending_Club_Analysis\Data\01_Raw_Data'

#Read in data
df = pd.read_csv(path + '/LoanStats_securev1_2020Q1.csv');

# %% [markdown]
# ## Data Overview

# %% [markdown]
# **Data Dictionary**

# %% [markdown]
# * **acceptD**: The date which the borrower accepted  the offer
# * **accNowDelinq**: The number of accounts on which the borrower is now delinquent.
# * **accOpenPast24Mths**: Number of trades opened in past 24 months.
# * **addrState**: The state provided by the borrower in the loan application
# * **all_util**: Balance to credit limit on all trades
# * **annual_inc_joint**: The combined self-reported annual income provided by the co-borrowers during registration
# * **annualInc**: The self-reported annual income provided by the borrower during registration.
# * **application_type**: Indicates whether the loan is an individual application or a joint application with two co-borrowers
# * **avg_cur_bal**: Average current balance of all accounts
# * **bcOpenToBuy**: Total open to buy on revolving bankcards.
# * **bcUtil**: Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# * **chargeoff_within_12_mths**: Number of charge-offs within 12 months
# * **collections_12_mths_ex_med**: Number of collections in 12 months excluding medical collections
# * **creditPullD**: The date LC pulled credit for this loan
# * **delinq2Yrs**: The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# * **delinqAmnt**: The past-due amount owed for the accounts on which the borrower is now delinquent.
# * **desc**: Loan description provided by the borrower
# * **dti**: A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# * **dti_joint**: A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
# * **earliestCrLine**: The date the borrower's earliest reported credit line was opened
# * **effective_int_rate**: The effective interest rate is equal to the interest rate on a Note reduced by Lending Club's estimate of the impact of uncollected interest prior to charge off.
# * **emp_title**: The job title supplied by the Borrower when applying for the loan.*
# * **empLength**: Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# * **expD**: The date the listing will expire
# * **expDefaultRate**: The expected default rate of the loan.
# * **ficoRangeHigh**: The upper boundary range the borrower’s FICO at loan origination belongs to.
# * **ficoRangeLow**: The lower boundary range the borrower’s FICO at loan origination belongs to.
# * **fundedAmnt**: The total amount committed to that loan at that point in time.
# * **grade**: LC assigned loan grade
# * **homeOwnership**: The home ownership status provided by the borrower during registration. Our values are: RENT, OWN, MORTGAGE, OTHER.
# * **id**: A unique LC assigned ID for the loan listing.
# * **il_util**: Ratio of total current balance to high credit/credit limit on all install acct
# * **ils_exp_d**: wholeloan platform expiration date
# * **initialListStatus**: The initial listing status of the loan. Possible values are – W, F
# * **inq_fi**: Number of personal finance inquiries
# * **inq_last_12m**: Number of credit inquiries in past 12 months
# * **inqLast6Mths**: The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# * **installment**: The monthly payment owed by the borrower if the loan originates.
# * **intRate**: Interest Rate on the loan
# * **isIncV**: Indicates if income was verified by LC, not verified, or if the income source was verified
# * **listD**: The date which the borrower's application was listed on the platform.
# * **loanAmnt**: The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# * **max_bal_bc**: Maximum current balance owed on all revolving accounts
# * **memberId**: A unique LC assigned Id for the borrower member.
# * **mo_sin_old_rev_tl_op**: Months since oldest revolving account opened
# * **mo_sin_rcnt_rev_tl_op**: Months since most recent revolving account opened
# * **mo_sin_rcnt_tl**: Months since most recent account opened
# * **mortAcc**: Number of mortgage accounts.
# * **msa**: Metropolitan Statistical Area of the borrower.
# * **mths_since_last_major_derog**: Months since most recent 90-day or worse rating
# * **mths_since_oldest_il_open**: Months since oldest bank installment account opened
# * **mths_since_rcnt_il**: Months since most recent installment accounts opened
# * **mthsSinceLastDelinq**: The number of months since the borrower's last delinquency.
# * **mthsSinceLastRecord**: The number of months since the last public record.
# * **mthsSinceMostRecentInq**: Months since most recent inquiry.
# * **mthsSinceRecentBc**: Months since most recent bankcard account opened.
# * **mthsSinceRecentLoanDelinq**: Months since most recent personal finance delinquency.
# * **mthsSinceRecentRevolDelinq**: Months since most recent revolving delinquency.
# * **num_accts_ever_120_pd**: Number of accounts ever 120 or more days past due
# * **num_actv_bc_tl**: Number of currently active bankcard accounts
# * **num_actv_rev_tl**: Number of currently active revolving trades
# * **num_bc_sats**: Number of satisfactory bankcard accounts
# * **num_bc_tl**: Number of bankcard accounts
# * **num_il_tl**: Number of installment accounts
# * **num_op_rev_tl**: Number of open revolving accounts
# * **num_rev_accts**: Number of revolving accounts
# * **num_rev_tl_bal_gt_0**: Number of revolving trades with balance >0
# * **num_sats**: Number of satisfactory accounts
# * **num_tl_120dpd_2m**: Number of accounts currently 120 days past due (updated in past 2 months)
# * **num_tl_30dpd**: Number of accounts currently 30 days past due (updated in past 2 months)
# * **num_tl_90g_dpd_24m**: Number of accounts 90 or more days past due in last 24 months
# * **num_tl_op_past_12m**: Number of accounts opened in past 12 months
# * **open_acc_6m**: Number of open trades in last 6 months
# * **open_il_12m**: Number of installment accounts opened in past 12 months
# * **open_il_24m**: Number of installment accounts opened in past 24 months
# * **open_act_il**: Number of currently active installment trades
# * **open_rv_12m**: Number of revolving trades opened in past 12 months
# * **open_rv_24m**: Number of revolving trades opened in past 24 months
# * **openAcc**: The number of open credit lines in the borrower's credit file.
# * **pct_tl_nvr_dlq**: Percent of trades never delinquent
# * **percentBcGt75**: Percentage of all bankcard accounts > 75% of limit.
# * **pub_rec_bankruptcies**: Number of public record bankruptcies
# * **pubRec**: Number of derogatory public records
# * **purpose**: A category provided by the borrower for the loan request.
# * **reviewStatus**: The status of the loan during the listing period. Values: APPROVED, NOT_APPROVED.
# * **reviewStatusD**: The date the loan application was reviewed by LC
# * **revolBal**: Total credit revolving balance
# * **revolUtil**: Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# * **serviceFeeRate**: Service fee rate paid by the investor for this loan.
# * **subGrade**: LC assigned loan subgrade
# * **tax_liens**: Number of tax liens
# * **term**: The number of payments on the loan. Values are in months and can be either 36 or 60.
# * **title**: The loan title provided by the borrower
# * **tot_coll_amt**: Total collection amounts ever owed
# * **tot_cur_bal**: Total current balance of all accounts
# * **tot_hi_cred_lim**: Total high credit/credit limit
# * **total_bal_il**: Total current balance of all installment accounts
# * **total_cu_tl**: Number of finance trades
# * **total_il_high_credit_limit**: Total installment high credit/credit limit
# * **total_rev_hi_lim**:  	Total revolving high credit/credit limit
# * **totalAcc**: The total number of credit lines currently in the borrower's credit file
# * **totalBalExMort**: Total credit balance excluding mortgage
# * **totalBcLimit**: Total bankcard high credit/credit limit
# * **url**: URL for the LC page with listing data.
# * **verified_status_joint**: Indicates if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified
# * **zip_code**: The first 3 numbers of the zip code provided by the borrower in the loan application.
# * **revol_bal_joint**: 	 Sum of revolving credit balance of the co-borrowers, net of duplicate balances
# * **sec_app_fico_range_low**: 	 FICO range (high) for the secondary applicant
# * **sec_app_fico_range_high**: 	 FICO range (low) for the secondary applicant
# * **sec_app_earliest_cr_line**: 	 Earliest credit line at time of application for the secondary applicant
# * **sec_app_inq_last_6mths**: 	 Credit inquiries in the last 6 months at time of application for the secondary applicant
# * **sec_app_mort_acc**: 	 Number of mortgage accounts at time of application for the secondary applicant
# * **sec_app_open_acc**: 	 Number of open trades at time of application for the secondary applicant
# * **sec_app_revol_util**: 	 Ratio of total current balance to high credit/credit limit for all revolving accounts
# * **sec_app_open_act_il**:  Number of currently active installment trades at time of application for the secondary applicant
# * **sec_app_num_rev_accts**: 	 Number of revolving accounts at time of application for the secondary applicant
# * **sec_app_chargeoff_within_12_mths**: 	 Number of charge-offs within last 12 months at time of application for the secondary applicant
# * **sec_app_collections_12_mths_ex_med**: 	 Number of collections within last 12 months excluding medical collections at time of application for the secondary applicant
# * **sec_app_mths_since_last_major_derog**: 	 Months since most recent 90-day or worse rating at time of application for the secondary applicant
# * **disbursement_method**: The method by which the borrower receives their loan. Possible values are: CASH, DIRECT_PAY

# %% [markdown]
# **Preview Data**

# %%
print('Data Shape:', df.shape)
display(df.head())
# Out:
# Data Shape: (105012, 150)
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  166795268        NaN       5000         5000             5000   36 months
# 1  168699409        NaN       8500         8500             8500   36 months
# 2  168692351        NaN       5000         5000             5000   36 months
# 3  168694393        NaN      15075        15075            15075   36 months
# 4  168689417        NaN       4000         4000             4000   36 months
#
#   int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0   18.62%       182.33     D        D1                       NaN        NaN
# 1   10.19%       275.03     A        A4    Sr. Operations Manager    4 years
# 2   10.19%       161.79     A        A4                       NaN        NaN
# 3   10.81%       492.19     A        A5   Environmental Scientist  10+ years
# 4   17.30%       143.21     C        C1  Financial Service Leader  10+ years
#
#   home_ownership  annual_inc verification_status issue_d loan_status  \
# 0            OWN     36000.0            Verified  Mar-20     Current
# 1       MORTGAGE    132000.0            Verified  Mar-20     Current
# 2       MORTGAGE     79470.0        Not Verified  Mar-20     Current
# 3       MORTGAGE     73000.0        Not Verified  Mar-20     Current
# 4       MORTGAGE    125000.0     Source Verified  Mar-20      Issued
#
#   pymnt_plan                                                url  desc  \
# 0          n  https://lendingclub.com/browse/loanDetail.acti...   NaN
# 1          n  https://lendingclub.com/browse/loanDetail.acti...   NaN
# 2          n  https://lendingclub.com/browse/loanDetail.acti...   NaN
# 3          n  https://lendingclub.com/browse/loanDetail.acti...   NaN
# 4          n  https://lendingclub.com/browse/loanDetail.acti...   NaN
#
#               purpose                    title zip_code addr_state    dti  \
# 0               other                    Other    780xx         TX  26.33
# 1      major_purchase           Major purchase    796xx         TX  23.38
# 2         credit_card  Credit card refinancing    166xx         PA  21.64
# 3  debt_consolidation       Debt consolidation    194xx         PA  35.12
# 4  debt_consolidation       Debt consolidation    124xx         NY  27.87
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0            0           May-15             670              674
# 1            0           Jan-09             790              794
# 2            0           Aug-06             740              744
# 3            0           Aug-06             755              759
# 4            0           Aug-98             680              684
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0               1                     NaN                     NaN         5
# 1               1                     NaN                     NaN        16
# 2               1                     NaN                    95.0        18
# 3               0                     NaN                     NaN        19
# 4               0                    47.0                     NaN        14
#
#    pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0        0      16452     70.90%          7                   f    4678.28
# 1        0       6394        13%         44                   w    7883.90
# 2        1      15931     39.80%         40                   w    4637.56
# 3        0      10429     25.30%         36                   w   13991.71
# 4        0      26848     93.20%         38                   w    4000.00
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        4678.28       541.82           541.82           321.72
# 1        7883.90       820.28           820.28           616.10
# 2        4637.56       482.54           482.54           362.44
# 3       13991.71      1467.52          1467.52          1083.29
# 4        4000.00         0.00             0.00             0.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         220.10                 0.0         0.0                      0.0
# 1         204.18                 0.0         0.0                      0.0
# 2         120.10                 0.0         0.0                      0.0
# 3         384.23                 0.0         0.0                      0.0
# 4           0.00                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0       Jun-20           182.33       Jul-20             Jun-20
# 1       Jun-20           275.03       Jul-20             Jun-20
# 2       Jun-20           161.79       Jul-20             Jun-20
# 3       Jun-20           492.19       Jul-20             Jun-20
# 4       Jun-20             0.00       Aug-20             Jun-20
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                   669                  665                           0
# 1                   784                  780                           0
# 2                   749                  745                           0
# 3                   744                  740                           0
# 4                   704                  700                           0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN            1       Individual
# 1                          NaN            1       Individual
# 2                          NaN            1        Joint App
# 3                          NaN            1       Individual
# 4                         49.0            1       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN               0
# 1               NaN        NaN                       NaN               0
# 2           90000.0      28.37              Not Verified               0
# 3               NaN        NaN                       NaN               0
# 4               NaN        NaN                       NaN               0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0             0        34683            0            1            1
# 1             0       326617            0            5            3
# 2             0       158428            2            9            2
# 3             0       426837            1            8            2
# 4             0       342153            0            6            1
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0            1                12.0         18231     90.0            0
# 1            6                 9.0        127815     84.0            0
# 2            2                 3.0         56790     80.0            1
# 3            3                 6.0        149873     92.0            0
# 4            4                11.0        114185     83.0            1
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0            1        8141      80.0             23200       2            0
# 1            4        2261      62.0             49000       2            5
# 2            4        9700      65.0             40000       2            1
# 3            1        5774      75.0             41300       1            2
# 4            2        9486      87.0             28800       1           13
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0             5                     2       6937.0          6748.0     70.9
# 1             7                    10      21774.0         30985.0     12.2
# 2             3                     6       8802.0         13161.0     54.5
# 3             0                     4      22465.0         23167.0     28.7
# 4             0                     6      24440.0           366.0     98.1
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                         0            0                57.0
# 1                         0            0               134.0
# 2                         0            0               139.0
# 3                         0            0               163.0
# 4                         0            0               259.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                    35                     23              12         0
# 1                   125                     14               9         2
# 2                   163                     11               3         3
# 3                   126                     24               6         1
# 4                   230                      7               7         4
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                  23.0                       NaN                    0.0
# 1                  14.0                       NaN                    5.0
# 2                  11.0                       NaN                    3.0
# 3                  24.0                       NaN                   13.0
# 4                   7.0                      49.0                   19.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                      0               4
# 1                             NaN                      0               2
# 2                             NaN                      0               4
# 3                             NaN                      0               2
# 4                            49.0                      3               4
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                4            4          4          3              4
# 1                3            6          7         25             10
# 2                6            4          4         26              8
# 3                5            5          5         20             10
# 4                7            4          9         16              7
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0              4                    4         5               0.0
# 1             17                    3        16               0.0
# 2             11                    6        18               0.0
# 3             15                    5        19               0.0
# 4             18                    7        14               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0             0                   0                   1           100.0
# 1             0                   0                   3           100.0
# 2             0                   0                   3           100.0
# 3             0                   0                   2            97.2
# 4             0                   0                   2            78.9
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              50.0                     0          0            43392
# 1               0.0                     0          0           401938
# 2               0.0                     1          0           224187
# 3               0.0                     0          0           483156
# 4             100.0                     0          0           376793
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0              34683           23200                       20192
# 1             134209           35300                      149688
# 2              72721           28900                       71245
# 3             160302           32500                      161856
# 4             141033           19200                      136583
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2          35481.0                   725.0                    729.0
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                   Aug-06                     1.0               3.0
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2              22.0                31.1                  3.0
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                   23.0                               0.0
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 0.0                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             Y     CVD19SKIP      INCOMECURT          ACTIVE            2.0
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              0.0              Apr-20            Jul-20
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                  May-20              2.0           0.0               ACTIVE
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                      115.33                         4046.13
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           0.0                    N
#
#    debt_settlement_flag_date  settlement_status  settlement_date  \
# 0                        NaN                NaN              NaN
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %% [markdown]
# **View Data Dtypes**

# %%
df.dtypes
# Out:
# id                                              int64
# member_id                                     float64
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                                 int64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# url                                            object
# desc                                          float64
# purpose                                        object
# title                                          object
# zip_code                                       object
# addr_state                                     object
# dti                                           float64
# delinq_2yrs                                     int64
# earliest_cr_line                               object
# fico_range_low                                  int64
# fico_range_high                                 int64
# inq_last_6mths                                  int64
# mths_since_last_delinq                        float64
# mths_since_last_record                        float64
# open_acc                                        int64
# pub_rec                                         int64
# revol_bal                                       int64
# revol_util                                     object
# total_acc                                       int64
# initial_list_status                            object
# out_prncp                                     float64
# out_prncp_inv                                 float64
# total_pymnt                                   float64
# total_pymnt_inv                               float64
# total_rec_prncp                               float64
# total_rec_int                                 float64
# total_rec_late_fee                            float64
# recoveries                                    float64
# collection_recovery_fee                       float64
# last_pymnt_d                                   object
# last_pymnt_amnt                               float64
# next_pymnt_d                                   object
# last_credit_pull_d                             object
# last_fico_range_high                            int64
# last_fico_range_low                             int64
# collections_12_mths_ex_med                      int64
# mths_since_last_major_derog                   float64
# policy_code                                     int64
# application_type                               object
# annual_inc_joint                              float64
# dti_joint                                     float64
# verification_status_joint                      object
# acc_now_delinq                                  int64
# tot_coll_amt                                    int64
# tot_cur_bal                                     int64
# open_acc_6m                                     int64
# open_act_il                                     int64
# open_il_12m                                     int64
# open_il_24m                                     int64
# mths_since_rcnt_il                            float64
# total_bal_il                                    int64
# il_util                                       float64
# open_rv_12m                                     int64
# open_rv_24m                                     int64
# max_bal_bc                                      int64
# all_util                                      float64
# total_rev_hi_lim                                int64
# inq_fi                                          int64
# total_cu_tl                                     int64
# inq_last_12m                                    int64
# acc_open_past_24mths                            int64
# avg_cur_bal                                   float64
# bc_open_to_buy                                float64
# bc_util                                       float64
# chargeoff_within_12_mths                        int64
# delinq_amnt                                     int64
# mo_sin_old_il_acct                            float64
# mo_sin_old_rev_tl_op                            int64
# mo_sin_rcnt_rev_tl_op                           int64
# mo_sin_rcnt_tl                                  int64
# mort_acc                                        int64
# mths_since_recent_bc                          float64
# mths_since_recent_bc_dlq                      float64
# mths_since_recent_inq                         float64
# mths_since_recent_revol_delinq                float64
# num_accts_ever_120_pd                           int64
# num_actv_bc_tl                                  int64
# num_actv_rev_tl                                 int64
# num_bc_sats                                     int64
# num_bc_tl                                       int64
# num_il_tl                                       int64
# num_op_rev_tl                                   int64
# num_rev_accts                                   int64
# num_rev_tl_bal_gt_0                             int64
# num_sats                                        int64
# num_tl_120dpd_2m                              float64
# num_tl_30dpd                                    int64
# num_tl_90g_dpd_24m                              int64
# num_tl_op_past_12m                              int64
# pct_tl_nvr_dlq                                float64
# percent_bc_gt_75                              float64
# pub_rec_bankruptcies                            int64
# tax_liens                                       int64
# tot_hi_cred_lim                                 int64
# total_bal_ex_mort                               int64
# total_bc_limit                                  int64
# total_il_high_credit_limit                      int64
# revol_bal_joint                               float64
# sec_app_fico_range_low                        float64
# sec_app_fico_range_high                       float64
# sec_app_earliest_cr_line                       object
# sec_app_inq_last_6mths                        float64
# sec_app_mort_acc                              float64
# sec_app_open_acc                              float64
# sec_app_revol_util                            float64
# sec_app_open_act_il                           float64
# sec_app_num_rev_accts                         float64
# sec_app_chargeoff_within_12_mths              float64
# sec_app_collections_12_mths_ex_med            float64
# sec_app_mths_since_last_major_derog           float64
# hardship_flag                                  object
# hardship_type                                  object
# hardship_reason                                object
# hardship_status                                object
# deferral_term                                 float64
# hardship_amount                               float64
# hardship_start_date                            object
# hardship_end_date                              object
# payment_plan_start_date                        object
# hardship_length                               float64
# hardship_dpd                                  float64
# hardship_loan_status                           object
# orig_projected_additional_accrued_interest    float64
# hardship_payoff_balance_amount                float64
# hardship_last_payment_amount                  float64
# debt_settlement_flag                           object
# debt_settlement_flag_date                     float64
# settlement_status                             float64
# settlement_date                               float64
# settlement_amount                             float64
# settlement_percentage                         float64
# settlement_term                               float64
# dtype: object

# %% [markdown]
# **Descriptive Stats About Data**

# %%
df.describe().T
# Out:
#                                                count          mean  \
# id                                          105012.0  1.662181e+08
# member_id                                        0.0           NaN
# loan_amnt                                   105012.0  1.682970e+04
# funded_amnt                                 105012.0  1.682970e+04
# funded_amnt_inv                             105012.0  1.682672e+04
# installment                                 105012.0  4.839120e+02
# annual_inc                                  105012.0  8.862647e+04
# desc                                             0.0           NaN
# dti                                         104820.0  2.160481e+01
# delinq_2yrs                                 105012.0  2.200987e-01
# fico_range_low                              105012.0  7.065306e+02
# fico_range_high                             105012.0  7.105307e+02
# inq_last_6mths                              105012.0  5.587742e-01
# mths_since_last_delinq                       44227.0  3.632826e+01
# mths_since_last_record                        9633.0  8.739354e+01
# open_acc                                    105012.0  1.213883e+01
# pub_rec                                     105012.0  9.310365e-02
# revol_bal                                   105012.0  1.906665e+04
# total_acc                                   105012.0  2.388957e+01
# out_prncp                                   105012.0  1.493230e+04
# out_prncp_inv                               105012.0  1.492974e+04
# total_pymnt                                 105012.0  2.530754e+03
# total_pymnt_inv                             105012.0  2.530258e+03
# total_rec_prncp                             105012.0  1.876317e+03
# total_rec_int                               105012.0  6.538744e+02
# total_rec_late_fee                          105012.0  2.902983e-02
# recoveries                                  105012.0  5.335638e-01
# collection_recovery_fee                     105012.0  1.176894e-03
# last_pymnt_amnt                             105012.0  1.012883e+03
# last_fico_range_high                        105012.0  7.242989e+02
# last_fico_range_low                         105012.0  7.201621e+02
# collections_12_mths_ex_med                  105012.0  1.487449e-02
# mths_since_last_major_derog                  21391.0  4.609294e+01
# policy_code                                 105012.0  1.000000e+00
# annual_inc_joint                             13207.0  1.431113e+05
# dti_joint                                    13207.0  2.045173e+01
# acc_now_delinq                              105012.0  4.856588e-04
# tot_coll_amt                                105012.0  1.549489e+02
# tot_cur_bal                                 105012.0  1.581073e+05
# open_acc_6m                                 105012.0  1.039367e+00
# open_act_il                                 105012.0  3.006333e+00
# open_il_12m                                 105012.0  8.045271e-01
# open_il_24m                                 105012.0  1.768455e+00
# mths_since_rcnt_il                          102693.0  1.733703e+01
# total_bal_il                                105012.0  4.122491e+04
# il_util                                      92434.0  6.915715e+01
# open_rv_12m                                 105012.0  1.232612e+00
# open_rv_24m                                 105012.0  2.480040e+00
# max_bal_bc                                  105012.0  6.809173e+03
# all_util                                    104996.0  5.513848e+01
# total_rev_hi_lim                            105012.0  4.449757e+04
# inq_fi                                      105012.0  1.259399e+00
# total_cu_tl                                 105012.0  1.632261e+00
# inq_last_12m                                105012.0  2.064069e+00
# acc_open_past_24mths                        105012.0  4.527806e+00
# avg_cur_bal                                 105005.0  1.418674e+04
# bc_open_to_buy                              103967.0  1.819135e+04
# bc_util                                     103907.0  4.942811e+01
# chargeoff_within_12_mths                    105012.0  5.932655e-03
# delinq_amnt                                 105012.0  1.376709e+00
# mo_sin_old_il_acct                          102693.0  1.270246e+02
# mo_sin_old_rev_tl_op                        105012.0  1.721062e+02
# mo_sin_rcnt_rev_tl_op                       105012.0  1.546429e+01
# mo_sin_rcnt_tl                              105012.0  7.952710e+00
# mort_acc                                    105012.0  1.359721e+00
# mths_since_recent_bc                        104036.0  2.449884e+01
# mths_since_recent_bc_dlq                     20436.0  3.891412e+01
# mths_since_recent_inq                        94579.0  6.995189e+00
# mths_since_recent_revol_delinq               29412.0  3.690140e+01
# num_accts_ever_120_pd                       105012.0  4.304937e-01
# num_actv_bc_tl                              105012.0  3.990096e+00
# num_actv_rev_tl                             105012.0  5.689578e+00
# num_bc_sats                                 105012.0  5.375186e+00
# num_bc_tl                                   105012.0  7.539976e+00
# num_il_tl                                   105012.0  9.140822e+00
# num_op_rev_tl                               105012.0  8.508323e+00
# num_rev_accts                               105012.0  1.318661e+01
# num_rev_tl_bal_gt_0                         105012.0  5.688912e+00
# num_sats                                    105012.0  1.212470e+01
# num_tl_120dpd_2m                            104355.0  9.582675e-05
# num_tl_30dpd                                105012.0  2.475908e-04
# num_tl_90g_dpd_24m                          105012.0  5.448901e-02
# num_tl_op_past_12m                          105012.0  2.185407e+00
# pct_tl_nvr_dlq                              105012.0  9.516277e+01
# percent_bc_gt_75                            103966.0  3.244563e+01
# pub_rec_bankruptcies                        105012.0  9.302746e-02
# tax_liens                                   105012.0  0.000000e+00
# tot_hi_cred_lim                             105012.0  2.047578e+05
# total_bal_ex_mort                           105012.0  6.082513e+04
# total_bc_limit                              105012.0  3.212485e+04
# total_il_high_credit_limit                  105012.0  5.314539e+04
# revol_bal_joint                              13207.0  4.343837e+04
# sec_app_fico_range_low                       13207.0  6.796441e+02
# sec_app_fico_range_high                      13207.0  6.836441e+02
# sec_app_inq_last_6mths                       13207.0  7.006133e-01
# sec_app_mort_acc                             13207.0  1.667373e+00
# sec_app_open_acc                             13207.0  1.208511e+01
# sec_app_revol_util                           13029.0  5.423349e+01
# sec_app_open_act_il                          13207.0  3.133793e+00
# sec_app_num_rev_accts                        13207.0  1.296116e+01
# sec_app_chargeoff_within_12_mths             13207.0  2.581964e-02
# sec_app_collections_12_mths_ex_med           13207.0  5.065496e-02
# sec_app_mths_since_last_major_derog           3681.0  3.888780e+01
# deferral_term                                10590.0  2.349481e+00
# hardship_amount                              13743.0  1.230380e+02
# hardship_length                              10590.0  2.349481e+00
# hardship_dpd                                 10589.0  4.904146e-01
# orig_projected_additional_accrued_interest   13743.0  6.220174e+02
# hardship_payoff_balance_amount               13743.0  1.692001e+04
# hardship_last_payment_amount                 13743.0  7.930636e+02
# debt_settlement_flag_date                        0.0           NaN
# settlement_status                                0.0           NaN
# settlement_date                                  0.0           NaN
# settlement_amount                                0.0           NaN
# settlement_percentage                            0.0           NaN
# settlement_term                                  0.0           NaN
#
#                                                      std           min  \
# id                                          1.389839e+06  1.619481e+08
# member_id                                            NaN           NaN
# loan_amnt                                   1.043736e+04  1.000000e+03
# funded_amnt                                 1.043736e+04  1.000000e+03
# funded_amnt_inv                             1.043659e+04  1.000000e+03
# installment                                 2.940335e+02  3.064000e+01
# annual_inc                                  9.889935e+04  0.000000e+00
# desc                                                 NaN           NaN
# dti                                         2.003731e+01  0.000000e+00
# delinq_2yrs                                 7.246680e-01  0.000000e+00
# fico_range_low                              3.556092e+01  6.600000e+02
# fico_range_high                             3.556144e+01  6.640000e+02
# inq_last_6mths                              8.206782e-01  0.000000e+00
# mths_since_last_delinq                      2.158340e+01  0.000000e+00
# mths_since_last_record                      2.314146e+01  4.000000e+00
# open_acc                                    6.093688e+00  0.000000e+00
# pub_rec                                     2.966440e-01  0.000000e+00
# revol_bal                                   2.409906e+04  0.000000e+00
# total_acc                                   1.251762e+01  2.000000e+00
# out_prncp                                   1.012742e+04  0.000000e+00
# out_prncp_inv                               1.012673e+04  0.000000e+00
# total_pymnt                                 3.813034e+03  0.000000e+00
# total_pymnt_inv                             3.812584e+03  0.000000e+00
# total_rec_prncp                             3.722956e+03  0.000000e+00
# total_rec_int                               5.195254e+02  0.000000e+00
# total_rec_late_fee                          9.748460e-01  0.000000e+00
# recoveries                                  1.212068e+02  0.000000e+00
# collection_recovery_fee                     3.677547e-01  0.000000e+00
# last_pymnt_amnt                             3.403761e+03 -1.310560e+03
# last_fico_range_high                        4.281827e+01  4.990000e+02
# last_fico_range_low                         4.430163e+01  0.000000e+00
# collections_12_mths_ex_med                  1.340422e-01  0.000000e+00
# mths_since_last_major_derog                 2.138455e+01  0.000000e+00
# policy_code                                 0.000000e+00  1.000000e+00
# annual_inc_joint                            8.540055e+04  1.300000e+04
# dti_joint                                   8.211591e+00  5.000000e-02
# acc_now_delinq                              2.246048e-02  0.000000e+00
# tot_coll_amt                                1.532422e+03  0.000000e+00
# tot_cur_bal                                 1.770091e+05  0.000000e+00
# open_acc_6m                                 1.209034e+00  0.000000e+00
# open_act_il                                 3.005344e+00  0.000000e+00
# open_il_12m                                 9.886006e-01  0.000000e+00
# open_il_24m                                 1.604246e+00  0.000000e+00
# mths_since_rcnt_il                          2.115655e+01  0.000000e+00
# total_bal_il                                4.999168e+04  0.000000e+00
# il_util                                     2.270982e+01  0.000000e+00
# open_rv_12m                                 1.489009e+00  0.000000e+00
# open_rv_24m                                 2.480840e+00  0.000000e+00
# max_bal_bc                                  6.341223e+03  0.000000e+00
# all_util                                    2.015274e+01  0.000000e+00
# total_rev_hi_lim                            4.031485e+04  0.000000e+00
# inq_fi                                      1.510203e+00  0.000000e+00
# total_cu_tl                                 2.823234e+00  0.000000e+00
# inq_last_12m                                2.320988e+00  0.000000e+00
# acc_open_past_24mths                        3.225416e+00  0.000000e+00
# avg_cur_bal                                 1.731247e+04  0.000000e+00
# bc_open_to_buy                              2.197569e+04  0.000000e+00
# bc_util                                     2.843187e+01  0.000000e+00
# chargeoff_within_12_mths                    8.832937e-02  0.000000e+00
# delinq_amnt                                 1.968887e+02  0.000000e+00
# mo_sin_old_il_acct                          5.856039e+01  0.000000e+00
# mo_sin_old_rev_tl_op                        9.944412e+01  5.000000e+00
# mo_sin_rcnt_rev_tl_op                       1.922506e+01  0.000000e+00
# mo_sin_rcnt_tl                              8.631410e+00  0.000000e+00
# mort_acc                                    1.759520e+00  0.000000e+00
# mths_since_recent_bc                        3.233881e+01  0.000000e+00
# mths_since_recent_bc_dlq                    2.209314e+01  0.000000e+00
# mths_since_recent_inq                       5.837013e+00  0.000000e+00
# mths_since_recent_revol_delinq              2.173087e+01  0.000000e+00
# num_accts_ever_120_pd                       1.362565e+00  0.000000e+00
# num_actv_bc_tl                              2.577778e+00  0.000000e+00
# num_actv_rev_tl                             3.535617e+00  0.000000e+00
# num_bc_sats                                 3.372183e+00  0.000000e+00
# num_bc_tl                                   4.681609e+00  0.000000e+00
# num_il_tl                                   7.631270e+00  0.000000e+00
# num_op_rev_tl                               5.072569e+00  0.000000e+00
# num_rev_accts                               8.010115e+00  2.000000e+00
# num_rev_tl_bal_gt_0                         3.523641e+00  0.000000e+00
# num_sats                                    6.091463e+00  0.000000e+00
# num_tl_120dpd_2m                            9.788691e-03  0.000000e+00
# num_tl_30dpd                                1.573314e-02  0.000000e+00
# num_tl_90g_dpd_24m                          3.974020e-01  0.000000e+00
# num_tl_op_past_12m                          1.935623e+00  0.000000e+00
# pct_tl_nvr_dlq                              8.440969e+00  0.000000e+00
# percent_bc_gt_75                            3.373875e+01  0.000000e+00
# pub_rec_bankruptcies                        2.965074e-01  0.000000e+00
# tax_liens                                   0.000000e+00  0.000000e+00
# tot_hi_cred_lim                             1.994956e+05  0.000000e+00
# total_bal_ex_mort                           5.848707e+04  0.000000e+00
# total_bc_limit                              2.901133e+04  0.000000e+00
# total_il_high_credit_limit                  5.216063e+04  0.000000e+00
# revol_bal_joint                             3.492431e+04  0.000000e+00
# sec_app_fico_range_low                      4.295796e+01  5.400000e+02
# sec_app_fico_range_high                     4.295796e+01  5.440000e+02
# sec_app_inq_last_6mths                      1.029043e+00  0.000000e+00
# sec_app_mort_acc                            1.869751e+00  0.000000e+00
# sec_app_open_acc                            6.880981e+00  0.000000e+00
# sec_app_revol_util                          2.584577e+01  0.000000e+00
# sec_app_open_act_il                         3.190154e+00  0.000000e+00
# sec_app_num_rev_accts                       8.463886e+00  0.000000e+00
# sec_app_chargeoff_within_12_mths            2.902050e-01  0.000000e+00
# sec_app_collections_12_mths_ex_med          3.236257e-01  0.000000e+00
# sec_app_mths_since_last_major_derog         2.332371e+01  0.000000e+00
# deferral_term                               7.156740e-01  2.000000e+00
# hardship_amount                             2.500880e+02  0.000000e+00
# hardship_length                             7.156740e-01  2.000000e+00
# hardship_dpd                                2.568228e+00  0.000000e+00
# orig_projected_additional_accrued_interest  7.744360e+02  0.000000e+00
# hardship_payoff_balance_amount              1.037012e+04  0.000000e+00
# hardship_last_payment_amount                2.767869e+03  0.000000e+00
# debt_settlement_flag_date                            NaN           NaN
# settlement_status                                    NaN           NaN
# settlement_date                                      NaN           NaN
# settlement_amount                                    NaN           NaN
# settlement_percentage                                NaN           NaN
# settlement_term                                      NaN           NaN
#
#                                                      25%           50%  \
# id                                          1.650231e+08  1.661861e+08
# member_id                                            NaN           NaN
# loan_amnt                                   8.500000e+03  1.500000e+04
# funded_amnt                                 8.500000e+03  1.500000e+04
# funded_amnt_inv                             8.500000e+03  1.500000e+04
# installment                                 2.615300e+02  4.110850e+02
# annual_inc                                  5.000000e+04  7.300000e+04
# desc                                                 NaN           NaN
# dti                                         1.339000e+01  1.977000e+01
# delinq_2yrs                                 0.000000e+00  0.000000e+00
# fico_range_low                              6.800000e+02  7.000000e+02
# fico_range_high                             6.840000e+02  7.040000e+02
# inq_last_6mths                              0.000000e+00  0.000000e+00
# mths_since_last_delinq                      1.900000e+01  3.300000e+01
# mths_since_last_record                      7.200000e+01  9.200000e+01
# open_acc                                    8.000000e+00  1.100000e+01
# pub_rec                                     0.000000e+00  0.000000e+00
# revol_bal                                   6.657000e+03  1.297650e+04
# total_acc                                   1.500000e+01  2.200000e+01
# out_prncp                                   7.093927e+03  1.311383e+04
# out_prncp_inv                               7.088702e+03  1.311383e+04
# total_pymnt                                 9.834325e+02  1.650760e+03
# total_pymnt_inv                             9.828000e+02  1.650060e+03
# total_rec_prncp                             5.887125e+02  1.012620e+03
# total_rec_int                               2.692100e+02  5.159550e+02
# total_rec_late_fee                          0.000000e+00  0.000000e+00
# recoveries                                  0.000000e+00  0.000000e+00
# collection_recovery_fee                     0.000000e+00  0.000000e+00
# last_pymnt_amnt                             2.392800e+02  4.040400e+02
# last_fico_range_high                        6.940000e+02  7.190000e+02
# last_fico_range_low                         6.900000e+02  7.150000e+02
# collections_12_mths_ex_med                  0.000000e+00  0.000000e+00
# mths_since_last_major_derog                 2.900000e+01  4.600000e+01
# policy_code                                 1.000000e+00  1.000000e+00
# annual_inc_joint                            9.458000e+04  1.250000e+05
# dti_joint                                   1.447000e+01  2.009000e+01
# acc_now_delinq                              0.000000e+00  0.000000e+00
# tot_coll_amt                                0.000000e+00  0.000000e+00
# tot_cur_bal                                 3.300050e+04  8.520550e+04
# open_acc_6m                                 0.000000e+00  1.000000e+00
# open_act_il                                 1.000000e+00  2.000000e+00
# open_il_12m                                 0.000000e+00  1.000000e+00
# open_il_24m                                 1.000000e+00  1.000000e+00
# mths_since_rcnt_il                          6.000000e+00  1.100000e+01
# total_bal_il                                1.139675e+04  2.718350e+04
# il_util                                     5.500000e+01  7.100000e+01
# open_rv_12m                                 0.000000e+00  1.000000e+00
# open_rv_24m                                 1.000000e+00  2.000000e+00
# max_bal_bc                                  2.674000e+03  5.188000e+03
# all_util                                    4.100000e+01  5.600000e+01
# total_rev_hi_lim                            1.950000e+04  3.390000e+04
# inq_fi                                      0.000000e+00  1.000000e+00
# total_cu_tl                                 0.000000e+00  0.000000e+00
# inq_last_12m                                0.000000e+00  1.000000e+00
# acc_open_past_24mths                        2.000000e+00  4.000000e+00
# avg_cur_bal                                 3.315000e+03  7.566000e+03
# bc_open_to_buy                              3.776500e+03  1.080900e+04
# bc_util                                     2.610000e+01  4.790000e+01
# chargeoff_within_12_mths                    0.000000e+00  0.000000e+00
# delinq_amnt                                 0.000000e+00  0.000000e+00
# mo_sin_old_il_acct                          8.600000e+01  1.310000e+02
# mo_sin_old_rev_tl_op                        9.700000e+01  1.560000e+02
# mo_sin_rcnt_rev_tl_op                       4.000000e+00  9.000000e+00
# mo_sin_rcnt_tl                              3.000000e+00  5.000000e+00
# mort_acc                                    0.000000e+00  1.000000e+00
# mths_since_recent_bc                        5.000000e+00  1.400000e+01
# mths_since_recent_bc_dlq                    2.200000e+01  3.600000e+01
# mths_since_recent_inq                       2.000000e+00  5.000000e+00
# mths_since_recent_revol_delinq              2.000000e+01  3.400000e+01
# num_accts_ever_120_pd                       0.000000e+00  0.000000e+00
# num_actv_bc_tl                              2.000000e+00  3.000000e+00
# num_actv_rev_tl                             3.000000e+00  5.000000e+00
# num_bc_sats                                 3.000000e+00  5.000000e+00
# num_bc_tl                                   4.000000e+00  7.000000e+00
# num_il_tl                                   4.000000e+00  7.000000e+00
# num_op_rev_tl                               5.000000e+00  7.000000e+00
# num_rev_accts                               8.000000e+00  1.100000e+01
# num_rev_tl_bal_gt_0                         3.000000e+00  5.000000e+00
# num_sats                                    8.000000e+00  1.100000e+01
# num_tl_120dpd_2m                            0.000000e+00  0.000000e+00
# num_tl_30dpd                                0.000000e+00  0.000000e+00
# num_tl_90g_dpd_24m                          0.000000e+00  0.000000e+00
# num_tl_op_past_12m                          1.000000e+00  2.000000e+00
# pct_tl_nvr_dlq                              9.330000e+01  1.000000e+02
# percent_bc_gt_75                            0.000000e+00  2.500000e+01
# pub_rec_bankruptcies                        0.000000e+00  0.000000e+00
# tax_liens                                   0.000000e+00  0.000000e+00
# tot_hi_cred_lim                             6.200000e+04  1.328245e+05
# total_bal_ex_mort                           2.494700e+04  4.490200e+04
# total_bc_limit                              1.250000e+04  2.400000e+04
# total_il_high_credit_limit                  1.964400e+04  4.000000e+04
# revol_bal_joint                             2.008900e+04  3.485000e+04
# sec_app_fico_range_low                      6.550000e+02  6.800000e+02
# sec_app_fico_range_high                     6.590000e+02  6.840000e+02
# sec_app_inq_last_6mths                      0.000000e+00  0.000000e+00
# sec_app_mort_acc                            0.000000e+00  1.000000e+00
# sec_app_open_acc                            7.000000e+00  1.100000e+01
# sec_app_revol_util                          3.480000e+01  5.500000e+01
# sec_app_open_act_il                         1.000000e+00  2.000000e+00
# sec_app_num_rev_accts                       7.000000e+00  1.100000e+01
# sec_app_chargeoff_within_12_mths            0.000000e+00  0.000000e+00
# sec_app_collections_12_mths_ex_med          0.000000e+00  0.000000e+00
# sec_app_mths_since_last_major_derog         2.100000e+01  3.700000e+01
# deferral_term                               2.000000e+00  2.000000e+00
# hardship_amount                             0.000000e+00  0.000000e+00
# hardship_length                             2.000000e+00  2.000000e+00
# hardship_dpd                                0.000000e+00  0.000000e+00
# orig_projected_additional_accrued_interest  2.120950e+02  4.161103e+02
# hardship_payoff_balance_amount              9.204765e+03  1.509379e+04
# hardship_last_payment_amount                2.125150e+02  3.854600e+02
# debt_settlement_flag_date                            NaN           NaN
# settlement_status                                    NaN           NaN
# settlement_date                                      NaN           NaN
# settlement_amount                                    NaN           NaN
# settlement_percentage                                NaN           NaN
# settlement_term                                      NaN           NaN
#
#                                                      75%           max
# id                                          1.673846e+08  1.686994e+08
# member_id                                            NaN           NaN
# loan_amnt                                   2.400000e+04  4.000000e+04
# funded_amnt                                 2.400000e+04  4.000000e+04
# funded_amnt_inv                             2.400000e+04  4.000000e+04
# installment                                 6.549700e+02  1.671880e+03
# annual_inc                                  1.050000e+05  9.999999e+06
# desc                                                 NaN           NaN
# dti                                         2.698000e+01  9.990000e+02
# delinq_2yrs                                 0.000000e+00  1.900000e+01
# fico_range_low                              7.250000e+02  8.450000e+02
# fico_range_high                             7.290000e+02  8.500000e+02
# inq_last_6mths                              1.000000e+00  5.000000e+00
# mths_since_last_delinq                      5.200000e+01  2.120000e+02
# mths_since_last_record                      1.070000e+02  1.190000e+02
# open_acc                                    1.500000e+01  6.900000e+01
# pub_rec                                     0.000000e+00  7.000000e+00
# revol_bal                                   2.330425e+04  1.107809e+06
# total_acc                                   3.100000e+01  1.290000e+02
# out_prncp                                   2.160953e+04  4.000000e+04
# out_prncp_inv                               2.160201e+04  4.000000e+04
# total_pymnt                                 2.742688e+03  4.282771e+04
# total_pymnt_inv                             2.741702e+03  4.282771e+04
# total_rec_prncp                             1.764355e+03  4.000000e+04
# total_rec_int                               8.978875e+02  5.116240e+03
# total_rec_late_fee                          0.000000e+00  7.747000e+01
# recoveries                                  0.000000e+00  3.000000e+04
# collection_recovery_fee                     0.000000e+00  1.190880e+02
# last_pymnt_amnt                             6.802425e+02  4.163450e+04
# last_fico_range_high                        7.540000e+02  8.500000e+02
# last_fico_range_low                         7.500000e+02  8.450000e+02
# collections_12_mths_ex_med                  0.000000e+00  1.000000e+01
# mths_since_last_major_derog                 6.300000e+01  2.120000e+02
# policy_code                                 1.000000e+00  1.000000e+00
# annual_inc_joint                            1.700000e+05  2.550000e+06
# dti_joint                                   2.633500e+01  3.999000e+01
# acc_now_delinq                              0.000000e+00  2.000000e+00
# tot_coll_amt                                0.000000e+00  2.916970e+05
# tot_cur_bal                                 2.387538e+05  4.155654e+06
# open_acc_6m                                 2.000000e+00  1.800000e+01
# open_act_il                                 4.000000e+00  5.900000e+01
# open_il_12m                                 1.000000e+00  1.300000e+01
# open_il_24m                                 3.000000e+00  2.800000e+01
# mths_since_rcnt_il                          2.000000e+01  4.320000e+02
# total_bal_il                                5.290500e+04  1.221659e+06
# il_util                                     8.500000e+01  2.520000e+02
# open_rv_12m                                 2.000000e+00  2.500000e+01
# open_rv_24m                                 4.000000e+00  3.400000e+01
# max_bal_bc                                  9.037000e+03  2.590240e+05
# all_util                                    6.900000e+01  1.850000e+02
# total_rev_hi_lim                            5.680000e+04  1.349000e+06
# inq_fi                                      2.000000e+00  3.900000e+01
# total_cu_tl                                 2.000000e+00  5.200000e+01
# inq_last_12m                                3.000000e+00  5.500000e+01
# acc_open_past_24mths                        6.000000e+00  3.900000e+01
# avg_cur_bal                                 1.963500e+04  8.311310e+05
# bc_open_to_buy                              2.458000e+04  3.960540e+05
# bc_util                                     7.300000e+01  1.738000e+02
# chargeoff_within_12_mths                    0.000000e+00  6.000000e+00
# delinq_amnt                                 0.000000e+00  4.332000e+04
# mo_sin_old_il_acct                          1.620000e+02  7.220000e+02
# mo_sin_old_rev_tl_op                        2.230000e+02  9.140000e+02
# mo_sin_rcnt_rev_tl_op                       2.000000e+01  3.720000e+02
# mo_sin_rcnt_tl                              1.000000e+01  1.960000e+02
# mort_acc                                    2.000000e+00  3.200000e+01
# mths_since_recent_bc                        3.100000e+01  5.520000e+02
# mths_since_recent_bc_dlq                    5.500000e+01  1.830000e+02
# mths_since_recent_inq                       1.000000e+01  2.500000e+01
# mths_since_recent_revol_delinq              5.100000e+01  2.120000e+02
# num_accts_ever_120_pd                       0.000000e+00  5.200000e+01
# num_actv_bc_tl                              5.000000e+00  3.200000e+01
# num_actv_rev_tl                             7.000000e+00  4.700000e+01
# num_bc_sats                                 7.000000e+00  4.800000e+01
# num_bc_tl                                   1.000000e+01  5.900000e+01
# num_il_tl                                   1.200000e+01  1.030000e+02
# num_op_rev_tl                               1.100000e+01  6.600000e+01
# num_rev_accts                               1.700000e+01  1.030000e+02
# num_rev_tl_bal_gt_0                         7.000000e+00  4.100000e+01
# num_sats                                    1.500000e+01  6.900000e+01
# num_tl_120dpd_2m                            0.000000e+00  1.000000e+00
# num_tl_30dpd                                0.000000e+00  1.000000e+00
# num_tl_90g_dpd_24m                          0.000000e+00  1.900000e+01
# num_tl_op_past_12m                          3.000000e+00  2.500000e+01
# pct_tl_nvr_dlq                              1.000000e+02  1.000000e+02
# percent_bc_gt_75                            5.000000e+01  1.000000e+02
# pub_rec_bankruptcies                        0.000000e+00  7.000000e+00
# tax_liens                                   0.000000e+00  0.000000e+00
# tot_hi_cred_lim                             2.970882e+05  4.275525e+06
# total_bal_ex_mort                           7.709275e+04  1.235436e+06
# total_bc_limit                              4.250000e+04  4.315000e+05
# total_il_high_credit_limit                  7.103800e+04  8.556770e+05
# revol_bal_joint                             5.598450e+04  4.515920e+05
# sec_app_fico_range_low                      7.050000e+02  8.350000e+02
# sec_app_fico_range_high                     7.090000e+02  8.390000e+02
# sec_app_inq_last_6mths                      1.000000e+00  6.000000e+00
# sec_app_mort_acc                            3.000000e+00  1.900000e+01
# sec_app_open_acc                            1.600000e+01  6.100000e+01
# sec_app_revol_util                          7.510000e+01  1.275000e+02
# sec_app_open_act_il                         4.000000e+00  4.500000e+01
# sec_app_num_rev_accts                       1.700000e+01  7.600000e+01
# sec_app_chargeoff_within_12_mths            0.000000e+00  1.700000e+01
# sec_app_collections_12_mths_ex_med          0.000000e+00  1.700000e+01
# sec_app_mths_since_last_major_derog         5.700000e+01  1.650000e+02
# deferral_term                               2.000000e+00  4.000000e+00
# hardship_amount                             1.321500e+02  1.549440e+03
# hardship_length                             2.000000e+00  4.000000e+00
# hardship_dpd                                0.000000e+00  3.400000e+01
# orig_projected_additional_accrued_interest  7.367316e+02  1.188378e+04
# hardship_payoff_balance_amount              2.409182e+04  4.250800e+04
# hardship_last_payment_amount                6.484000e+02  4.027098e+04
# debt_settlement_flag_date                            NaN           NaN
# settlement_status                                    NaN           NaN
# settlement_date                                      NaN           NaN
# settlement_amount                                    NaN           NaN
# settlement_percentage                                NaN           NaN
# settlement_term                                      NaN           NaN

# %% [markdown]
# **Missing Data**

# %%
from Missing_Values import missing_counts
missing_counts(df)
# Out:
#                                             missing_count   missing_%  \
# member_id                                          105012  100.000000
# debt_settlement_flag_date                          105012  100.000000
# settlement_percentage                              105012  100.000000
# settlement_amount                                  105012  100.000000
# settlement_date                                    105012  100.000000
# settlement_status                                  105012  100.000000
# settlement_term                                    105012  100.000000
# desc                                               105012  100.000000
# sec_app_mths_since_last_major_derog                101331   96.494686
# mths_since_last_record                              95379   90.826763
# hardship_loan_status                                95148   90.606788
# hardship_dpd                                        94423   89.916391
# hardship_reason                                     94423   89.916391
# deferral_term                                       94422   89.915438
# hardship_type                                       94422   89.915438
# hardship_length                                     94422   89.915438
# payment_plan_start_date                             94422   89.915438
# hardship_end_date                                   94422   89.915438
# hardship_start_date                                 94422   89.915438
# hardship_status                                     94422   89.915438
# verification_status_joint                           93447   88.986973
# sec_app_revol_util                                  91983   87.592847
# sec_app_inq_last_6mths                              91805   87.423342
# sec_app_collections_12_mths_ex_med                  91805   87.423342
# sec_app_chargeoff_within_12_mths                    91805   87.423342
# sec_app_num_rev_accts                               91805   87.423342
# sec_app_open_act_il                                 91805   87.423342
# sec_app_open_acc                                    91805   87.423342
# sec_app_mort_acc                                    91805   87.423342
# sec_app_earliest_cr_line                            91805   87.423342
# sec_app_fico_range_high                             91805   87.423342
# sec_app_fico_range_low                              91805   87.423342
# revol_bal_joint                                     91805   87.423342
# annual_inc_joint                                    91805   87.423342
# dti_joint                                           91805   87.423342
# hardship_amount                                     91269   86.912924
# hardship_last_payment_amount                        91269   86.912924
# hardship_payoff_balance_amount                      91269   86.912924
# orig_projected_additional_accrued_interest          91269   86.912924
# mths_since_recent_bc_dlq                            84576   80.539367
# mths_since_last_major_derog                         83621   79.629947
# mths_since_recent_revol_delinq                      75600   71.991772
# mths_since_last_delinq                              60785   57.883861
# emp_title                                           15706   14.956386
# il_util                                             12578   11.977679
# mths_since_recent_inq                               10433    9.935055
# emp_length                                           9095    8.660915
# next_pymnt_d                                         4255    4.051918
# hardship_flag                                        3153    3.002514
# mths_since_rcnt_il                                   2319    2.208319
# mo_sin_old_il_acct                                   2319    2.208319
# bc_util                                              1105    1.052261
# percent_bc_gt_75                                     1046    0.996077
# bc_open_to_buy                                       1045    0.995124
# mths_since_recent_bc                                  976    0.929418
# num_tl_120dpd_2m                                      657    0.625643
# dti                                                   192    0.182836
# revol_util                                            127    0.120939
# last_pymnt_d                                           56    0.053327
# all_util                                               16    0.015236
# avg_cur_bal                                             7    0.006666
#
#                                            data_type
# member_id                                    float64
# debt_settlement_flag_date                    float64
# settlement_percentage                        float64
# settlement_amount                            float64
# settlement_date                              float64
# settlement_status                            float64
# settlement_term                              float64
# desc                                         float64
# sec_app_mths_since_last_major_derog          float64
# mths_since_last_record                       float64
# hardship_loan_status                          object
# hardship_dpd                                 float64
# hardship_reason                               object
# deferral_term                                float64
# hardship_type                                 object
# hardship_length                              float64
# payment_plan_start_date                       object
# hardship_end_date                             object
# hardship_start_date                           object
# hardship_status                               object
# verification_status_joint                     object
# sec_app_revol_util                           float64
# sec_app_inq_last_6mths                       float64
# sec_app_collections_12_mths_ex_med           float64
# sec_app_chargeoff_within_12_mths             float64
# sec_app_num_rev_accts                        float64
# sec_app_open_act_il                          float64
# sec_app_open_acc                             float64
# sec_app_mort_acc                             float64
# sec_app_earliest_cr_line                      object
# sec_app_fico_range_high                      float64
# sec_app_fico_range_low                       float64
# revol_bal_joint                              float64
# annual_inc_joint                             float64
# dti_joint                                    float64
# hardship_amount                              float64
# hardship_last_payment_amount                 float64
# hardship_payoff_balance_amount               float64
# orig_projected_additional_accrued_interest   float64
# mths_since_recent_bc_dlq                     float64
# mths_since_last_major_derog                  float64
# mths_since_recent_revol_delinq               float64
# mths_since_last_delinq                       float64
# emp_title                                     object
# il_util                                      float64
# mths_since_recent_inq                        float64
# emp_length                                    object
# next_pymnt_d                                  object
# hardship_flag                                 object
# mths_since_rcnt_il                           float64
# mo_sin_old_il_acct                           float64
# bc_util                                      float64
# percent_bc_gt_75                             float64
# bc_open_to_buy                               float64
# mths_since_recent_bc                         float64
# num_tl_120dpd_2m                             float64
# dti                                          float64
# revol_util                                    object
# last_pymnt_d                                  object
# all_util                                     float64
# avg_cur_bal                                  float64
